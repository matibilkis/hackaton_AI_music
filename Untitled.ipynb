# %%
import pyOSC3
import time, random
client = pyOSC3.OSCClient()
client.connect( ( '127.0.0.1', 57120 ) )
msg = pyOSC3.OSCMessage()
msg.setAddress("/print")
msg.append(500)
client.send(msg)

# %%
import matplotlib.pyplot as plt

from matplotlib import cm
from collections import OrderedDict

cmaps = OrderedDict()
cmaps['Sequential'] = [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']

# %%
import numpy as np

# %%
x = np.linspace(0,1,100)
y = np.linspace(0,1,100)
x,y = np.meshgrid(x,y)

# %%
def z(x,y, p, ini=2):
    image_array = 0
    for indi,k in zip(range(ini,ini+ len(p)+1), p ):
        image_array+= k*np.sin(indi*x*np.pi/2)*np.sin(indi*y*np.pi/2)
    return image_array

# %%
x = np.linspace(-1,1,100)
y = np.linspace(-1,1,100)
plt.figure(figsize=(10,10))
Nim=5
for i in range(Nim):
    ax = plt.subplot2grid((1,Nim+1), (0,i))
    p=np.array([np.random.uniform() for k in range(2)])
    ax = plt.imshow(np.array([[z(xi, yi,p) for xi in x] for yi in y]))

# %%
x = np.linspace(0,1,100)
y = np.linspace(0,1,100)
x,y = np.meshgrid(x,y)

def z(x,y, p, ini=2):
    image_array = 0
    for indi,k in zip(range(ini,ini+ len(p)+1), p ):
        image_array+= k*np.sin(indi*x*np.pi/2, cmap='binary_r')#*np.sin(indi*y*np.pi/2)
    return image_array

# %%
cmaps['Miscellaneous'] = [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg',
            'gist_rainbow', 'rainbow', 'jet', 'turbo', 'nipy_spectral',
            'gist_ncar']

name = cmaps['Miscellaneous']["gnuplot"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-465d3728d534> in <module>
#       5             'gist_ncar']
#       6
# ----> 7 name = cmaps['Miscellaneous']["gnuplot"]
#
# TypeError: list indices must be integers or slices, not str

# %%
plt.figure(figsize=(100,10))
Nim=10
for i in range(Nim):
    ax = plt.subplot2grid((1,Nim+1), (0,i))
    p=np.array([np.random.uniform() for k in range(2)])
    ax = plt.imshow(z(x,y,p,ini=3),  cmap=plt.get_cmap(name))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-a201b34606a1> in <module>
#       4     ax = plt.subplot2grid((1,Nim+1), (0,i))
#       5     p=np.array([np.random.uniform() for k in range(2)])
# ----> 6     ax = plt.imshow(z(x,y,p,ini=3),  cmap='binary_r')
#
# <ipython-input-74-fc1e25b7051b> in z(x, y, p, ini)
#       6     image_array = 0
#       7     for indi,k in zip(range(ini,ini+ len(p)+1), p ):
# ----> 8         image_array+= k*np.sin(indi*x*np.pi/2, cmap='binary_r')#*np.sin(indi*y*np.pi/2)
#       9     return image_array
#
# TypeError: 'cmap' is an invalid keyword to ufunc 'sin'

# %%
plt.imshow(np.random.randn(10,10))

# %%
ini = 0

for ind, pel in enumerate(p):
    arr += pel*np.sin((ind+ini)*np.pi*x)*np.sin((ind+ini)*np.pi*y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-f3855264924d> in <module>
#       1 ini = 0
#       2
# ----> 3 for ind, pel in enumerate(p):
#       4     arr += pel*np.sin((ind+ini)*np.pi*x)*np.sin((ind+ini)*np.pi*y)
#
# TypeError: 'float' object is not iterable
